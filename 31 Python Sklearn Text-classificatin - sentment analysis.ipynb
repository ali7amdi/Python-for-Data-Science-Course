# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
import mysql.connector
from mysql.connector import errorcode, connect
import re
from nltk.tokenize import word_tokenize
from nltk.stem.isri import ISRIStemmer
import itertools
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import cross_validation
from sklearn.metrics import classification_report
from sklearn.naive_bayes import MultinomialNB, GaussianNB, BernoulliNB
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC

# %%
def connectMysql():
    try:
        cnn = connect(
            user='root', 
            password='root', 
            host='localhost', 
            database='test',
            unix_socket='/Applications/MAMP/tmp/mysql/mysql.sock')
        return cnn
    except mysql.connector.Error as e:
        if e.errno == errorcode.ER_ACCESS_DENIED_ERROR:
            print ("Access denied!")
        elif e.errno == errorcode.ER_BAD_DB_ERROR:
            print ("Database does not exist.")
        else:
            print (e)

# %%
def getData(sql):
    cnn = connectMysql()
    cursor = cnn.cursor()
    cursor.execute(sql)
    reviews = DataFrame(cursor.fetchall())
    reviews.rename(columns={0:'text', 1:'label'}, inplace=True)
    cursor.close()
    cnn.close()
    return reviews

# %%
sql ="SELECT * FROM `REVIEWS`"
reviews = getData(sql)
len(reviews)
# Out:
# 8340

# %%
reviews
# Out:
#                                                    text  label
# 0     اولا: المنيو تغير الشورما اصبحت اعتياديه بأختف...     -1
# 1     من محلات الشاورما ذات الشعبيه لتميز الصلصات ال...     -1
# 2     دجاج طازج يحضر امامك على الطلب لا يقوم باعدة ا...      1
# 3     فكما تعرف أستراليا بالكنغر والكوالا. فإنها تعر...      1
# 4     إسمحو لي أن أقيم مطعم هاشم بصفتي فلسطيني عشت ف...     -1
# 5     دعاية المطعم وسمعته أكبر بكثير من مستوى وجباته...     -1
# 6     انا من 5 سنوات كنت اكل فيه \n كان طعم هاشم الم...     -1
# 7     مقبول واسعاره جيدة  \n بالنسبة للفلافل والحمص ...      1
# 8               جربت نوع محشي فلفل ماعجبني مررة كان نيئ     -1
# 9     المطعم. رائع  والأكل نظيف وش هالحسد اللهم يا  ...      1
# 10    اثناء طلب الوجبه من المحاسب لا يوجد تنظيم  ويت...     -1
# 11    الحمص البيروتي والمسبحة وغيرها من الأصناف كانو...     -1
# 12                 ولا اروع من الفلافل و الحمص شئ خيالي      1
# 13    لطالما تقل الخيارات العربية في الدول الغير عرب...      1
# 14    هذا المطعم يقدم وجبات مغربية وعربية. المكان مر...      1
# 15    أنا شخصياً أحب مطاعم كنتاكي KFC \n خاصةً في ال...      1
# 16    المطعم جميل و أجواء جلساته لطيفة مكان جميل لتج...      1
# 17    قمت اليوم بزياره لهذا المطعم طلبي تيك اوي    ا...     -1
# 18                                     فطووور رائئئئئئع      1
# 19    مطعم ابوجبارة فروعه شارع المدينة المنورة شارع ...      1
# 20    السلام عليكم \n  \n قد يكون المسندوتش حلو المذ...      1
# 21    الميزات : \n 1/النظافة . \n 2/طريقة مختلفة عن ...      1
# 22    المميزات: \n  \n + مطعم لديه ضمير و شجاعة يمنع...     -1
# 23    حاولت أجرب أغلب الأنواع اللي عندهم مره وحده عش...      1
# 24    للأسف الشديد أن فرع بريدة سيء وخصوصا النظافة ....      1
# 25    أهم ما يميز المطعم عن غيره من مطاعم الوجبات ال...      1
# 26    ممكن كلامي ماراح يعجب البعض . لكن هذا المطعم خ...     -1
# 27    برجر فيول أكتسب شعبية كبيرة عند أهالي مدينة ال...      1
# 28    كنت أطلب من عنده BMT وكان طعمها جدًا رائع، لكن...      1
# 29    صراحه افضل مطعم بالنسبه لي من ناحيه الاسعار  \...      1
# ...                                                 ...    ...
# 8310                           بصراحه طعممممم وانصح بيه      1
# 8311                                العمل في النهار فقط      1
# 8312                                 شوربة وتقاطيع كويس     -1
# 8313  لذيذ ونظيفً ويرفع راسك عند ضيوفك  بس المظغوط م...      1
# 8314         للأسف تم اقفال المطبخ والآن ليس له فرع آخر      1
# 8315  جدا لذيذ واسعارة جدا رخيصه  025360168  جربووة ...      1
# 8316  بصراحة الطعم فناااااااااااااااان مرة  \n  \n ك...      1
# 8317  رحته وحده مرة مع خطيبي .. طلبت ايدام دجاج ماعج...      1
# 8318  المطعم جديد ,ديكوراته جميله ,اكلهم جيد ونظيف ,...      1
# 8319  بصراحة جربتو من كم يوم! \n  \n اطباق رائعة، وط...      1
# 8320  مطعم اكله لذيذ هاادي الخدمه سريعه رومنسي لدرجة...      1
# 8321  زرت المطعم اليوم بتاريخ 1435/10/13 \n فرع الشر...      1
# 8322  أول ما لفت إنتباهي هو الأسعار و جودة الوجبة ال...      1
# 8323  يوجد في الدورالثالث في سوق ذي المجاز مطعم جو ع...      1
# 8324  يتميز بالرز البرياني - لحم - دجاج \n  \n طعم ر...      1
# 8325  يحتوي على  أشهى و ألذ الأطباق  \n مطعم مزدحم د...      1
# 8326  بصراحة الطعم رهيييييييييييب \n  \n  \n تحس بنك...      1
# 8327             حاليا تم تجربة كباب ونقانق وكانت كويسه      1
# 8328                            المطعم وهمي على ما يبدو     -1
# 8329  مغلق منذ  سنة نظراً لخطورته على صحة المجتمع  ع...     -1
# 8330  المطعم جيد جداً لكنه صغير جدا لدرجة اقتصار خدم...     -1
# 8331  صراحة اكثر من روعة المطعم من ناحية الجودة الخد...      1
# 8332  المكان المناسب لمن يبحث عن الطعم اللذيذ و الطع...      1
# 8333                           يا لبا هل مطعم جناااااان      1
# 8334  هذا المطعم من افضل المطاعم بالمنطقة الجنوبية ب...      1
# 8335  أتمنى تعملو بطاقات خاصة أو ذهبية للعملاء الدائ...      1
# 8336  المشويات عندهم اطيب مشويات اكلتها بحياتي والاس...      1
# 8337  المطعم ممتاز للغايه ، من ناحيه تجهيزات المطعم ...      1
# 8338  جينا عندهم الساعة 10 بالليل مافى احد اتبرع يشو...     -1
# 8339  اذا كان اللي بالشارع التجاري اوووه ماشاء الله ...      1
#
# [8340 rows x 2 columns]

# %% [markdown]
# # Preprocessing

# %%
def noramlize(text):
    text = re.sub(r"[إأٱآا]", "ا", text)
    text = re.sub(r"ى", "ي", text)
    text = re.sub(r"ؤ", "ء", text)
    text = re.sub(r"ئ", "ء", text)
    text = re.sub(r'[^ا-ي ]', "", text)

    noise = re.compile(""" ّ    | # Tashdid
                             َ    | # Fatha
                             ً    | # Tanwin Fath
                             ُ    | # Damma
                             ٌ    | # Tanwin Damm
                             ِ    | # Kasra
                             ٍ    | # Tanwin Kasr
                             ْ    | # Sukun
                             ـ     # Tatwil/Kashida
                         """, re.VERBOSE)
    text = re.sub(noise, '', text)
    return text

# %%
# Normalize Arabic Text @ http://maximromanov.github.io/2013/01-02.html

# %%
def stopWordRmove(text):
    ar_stop_list = open("ar_stop_word_list.txt", "r")
    stop_words = ar_stop_list.read().split('\n')
    needed_words = []
    words = word_tokenize(text)
    for w in words:
        if w not in (stop_words):
            needed_words.append(w)
    filtered_sentence = " ".join(needed_words)
    return filtered_sentence

# %%
# Stemming ISRIStemmer @ http://www.nltk.org/_modules/nltk/stem/isri.html

# %%
def stemming(text):
    st = ISRIStemmer()
    stemmed_words = []
    words = word_tokenize(text)
    for w in words:
        stemmed_words.append(st.stem(w))
    stemmed_sentence = " ".join(stemmed_words)
    return stemmed_sentence

# %%
def prepareDataSets(reviews):
    sentences = []
    for index, r in reviews.iterrows():
        text = stopWordRmove(r['text'])
        text = noramlize(r['text'])
        text = stemming(r['text'])
        
        if r['label'] == -1:
            sentences.append([text, 'neg'])
        else:
            sentences.append([text, 'pos'])
    df_sentences = DataFrame(sentences, columns=['text', 'label'])
    return df_sentences

# %%
preprocessed_reviews = prepareDataSets(reviews)

# %%
preprocessed_reviews
# Out:
#                                                    text label
# 0     اول : نيو تغر شور صبح اعتياديه أختفاء صلص خير ...   neg
# 1     من محل شور ذات شعب تمز صلص قدم عها يمكن خير شو...   neg
# 2     دجج طزج حضر ممك على طلب لا يقم بعد تسخ تخذ بشر...   pos
# 3     فكم عرف رال كنغر كلا . فإن عرف ايض أكل مثل فيج...   pos
# 4     محو لي ان اقم طعم هشم بصف لسط عشت في ارد 24 عا...   neg
# 5     دعي طعم سمع كبر كثر من ستى وجب . جرب وكن عقد ا...   neg
# 6     انا من 5 سنو كنت اكل فيه كان طعم هشم ميز فول ح...   neg
# 7     قبل سعر جيد نسب لفل حمص فول يجي ابو جبر رتب ول...   pos
# 8                      جرب نوع حشي لفل اعجب ررة كان نيئ   neg
# 9     طعم . رئع اكل نظف وش هالحسد لهم يا كفي الل قعد...   pos
# 10    ثنء طلب وجب من حسب لا وجد نظم يتم قدم شخص عن ا...   neg
# 11    حمص يرو سبح وغر من صنف كان واوووووو لفل حلو بس...   neg
# 12                          ولا ارع من لفل و حمص شئ خيل   pos
# 13    لطل تقل خير عرب في دول غير عرب . في رال قلل ما...   pos
# 14    هذا طعم قدم وجب غرب عرب . كان ريح جدا ديكور رئ...   pos
# 15    انا شخص احب طعم كنت KFC خصة في ارد حيث انه تمز...   pos
# 16    طعم جمل و جوء جلس لطف كان جمل جمع فية مع صدقاء...   pos
# 17    قمت اليوم زير لهذا طعم طلب تيك اوي جلس حله ديك...   neg
# 18                                      طووور رائئئئئئع   pos
# 19    طعم ابوجبارة فرع شرع دين نور شرع مكة قبل جمع ج...   pos
# 20    سلم علي قد يكون مسندوتش حلو ذاق فسد بعض اضف ، ...   pos
# 21    ميز : 1/النظافة . 2/طريق خلف عن طعم خرى وذل با...   pos
# 22    ميز : + طعم لده ضمر و شجع منع تدخ دخل طعم ، عك...   neg
# 23    حول جرب غلب واع الل عند مره وحد عشن عرف هم تمم...   pos
# 24    اسف شدد ان فرع برد سيء خصص نظف ... تخل حسب صري...   pos
# 25    اهم ما يمز طعم عن غير من طعم وجب سرع هو انك خا...   pos
# 26    مكن كلم ارح عجب بعض . لكن هذا طعم خطر على صحة ...   neg
# 27    رجر فيل كسب شعب كبر عند هلي دين خبر .. طعم في ...   pos
# 28    كنت طلب من عند BMT وكان طعم جدا رائع، لكن حين ...   pos
# 29    صرح فضل طعم نسب لي من نحي سعر و طعم ديش p : و ...   pos
# ...                                                 ...   ...
# 8310                                صرح طعممممم نصح بيه   pos
# 8311                                     عمل في نهر فقط   pos
# 8312                                       شورب قطع كوس   neg
# 8313             لذذ نظف رفع رسك عند ضيف بس ظغط ما زبطو   pos
# 8314                  اسف تم قفل طبخ ولآ ليس له فرع اخر   pos
# 8315  جدا لذذ سعر جدا رخص 025360168 جربوو احد زار وذ...   pos
# 8316  صرح طعم فنااااااااااااااا مرة كأن عزم عزم ( يع...   pos
# 8317  رحت وحد مرة مع خطب .. طلب يدم دجج اعجب طلب رز ...   pos
# 8318  طعم جدد , ديكوراته جمل , اكل جيد نظف , خدم ميز...   pos
# 8319  صرح جربتو من كم يوم ! طبق رائعة، طعم ذيذ، و خص...   pos
# 8320  طعم اكل لذذ هاد خدم سرع رومنس درج عمى ضااء معد...   pos
# 8321  زرت طعم اليوم ارخ 1435/10/13 فرع شرع بمك عندم ...   pos
# 8322  اول ما لفت نبه هو سعر و جود وجب مقدمة، اشء الل...   pos
# 8323  وجد في دورالثالث في سوق ذي جاز طعم جو عئل دلز ...   pos
# 8324  تمز لرز برا - لحم - دجج طعم رئع لذذ ( اسم على ...   pos
# 8325  حوي على شهى و الذ طبق طعم زدحم دائ سحق ربع على...   pos
# 8326  صرح طعم رهيييييييييييب تحس بنك اكل جوي فعل كنه...   pos
# 8327                       حال تم جرب كبب قنق وكانت كوس   pos
# 8328                                 طعم وهم على ما بدو   neg
# 8329  غلق منذ سنة نظر خطر على صحة جمع عمل يمن كان يض...   neg
# 8330  طعم جيد جدا لكن صغر جدا درج قصر خدم على الـ & ...   neg
# 8331  صرح كثر من روع طعم من نحي جود خدم قبل نظف نقص ...   pos
# 8332  كان نسب لمن بحث عن طعم لذذ و طعم فيد و سعر فرد...   pos
# 8333                                  يا لبا هل طعم جنا   pos
# 8334  هذا طعم من فضل طعم نطق جنب بل وبلمملكة ونا من ...   pos
# 8335  منى عملو بطق خصة او ذهب عملاء دئم يكون لهم وضع...   pos
# 8336  شوي عند اطب شوي اكل بحا قبل مرة حلو نظافةةةةةة...   pos
# 8337  طعم متز غيه ، من نحي جهز طعم ، ويض من نحي أكل ...   pos
# 8338  جين عند سعة 10 ليل افى احد برع شوفل طال فضي جل...   neg
# 8339        اذا كان الل شرع جري اوو اشء الل ولل انه خبل   pos
#
# [8340 rows x 2 columns]

# %%
# Feature Extraction

# %%
def featureExtraction(data):
    vectorizer = TfidfVectorizer(min_df=10, max_df=0.75, ngram_range=(1,3))
    tfidf_data = vectorizer.fit_transform(data)
    return tfidf_data

# %%
def learning(clf, X, Y):
    X_train, X_test, Y_train, Y_test = cross_validation.train_test_split(X,Y, test_size=0.4, random_state=43)
    
    classifer = clf()
    classifer.fit(X_train, Y_train)
    
    predict = cross_validation.cross_val_predict(classifer, X_test, Y_test, cv=10)
    
    scores = cross_validation.cross_val_score(classifer,X_test, Y_test, cv=10)
    
    print (scores)
    
    print ("Accuracy of %s: %0.2f (+/- %0.2f)" % (classifer, scores.mean(), scores.std() *2))
    print (classification_report(Y_test, predict))

# %%
def main(clf):
    reviews = getData("SELECT * FROM `REVIEWS` LIMIT 3000")
    preprocessed_reviews = prepareDataSets(reviews)
    data, target = preprocessed_reviews['text'], preprocessed_reviews['label']
    tfidf_data = featureExtraction(data)
    learning(clf, tfidf_data, target)

# %%
main(MultinomialNB)
# Out:
# [ 0.75206612  0.71900826  0.7107438   0.7107438   0.73553719  0.72268908
#   0.76470588  0.75630252  0.78991597  0.76470588]
# Accuracy of MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True): 0.74 (+/- 0.05)
#              precision    recall  f1-score   support
#
#         neg       0.84      0.29      0.44       405
#         pos       0.73      0.97      0.83       795
#
# avg / total       0.77      0.74      0.70      1200

# %%
clfs = [MultinomialNB, BernoulliNB, LogisticRegression, SGDClassifier, SVC, LinearSVC, NuSVC]

# %%
for clf in clfs:
    main(clf)
# Out:
# [ 0.75206612  0.71900826  0.7107438   0.7107438   0.73553719  0.72268908
#   0.76470588  0.75630252  0.78991597  0.76470588]
# Accuracy of MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True): 0.74 (+/- 0.05)
#              precision    recall  f1-score   support
#
#         neg       0.84      0.29      0.44       405
#         pos       0.73      0.97      0.83       795
#
# avg / total       0.77      0.74      0.70      1200
#
# [ 0.79338843  0.74380165  0.7768595   0.71900826  0.73553719  0.72268908
#   0.80672269  0.68907563  0.74789916  0.65546218]
# Accuracy of BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True): 0.74 (+/- 0.09)
#              precision    recall  f1-score   support
#
#         neg       0.64      0.51      0.57       405
#         pos       0.77      0.86      0.81       795
#
# avg / total       0.73      0.74      0.73      1200
#
# [ 0.76859504  0.74380165  0.74380165  0.75206612  0.75206612  0.74789916
#   0.77310924  0.7394958   0.79831933  0.75630252]
# Accuracy of LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False): 0.76 (+/- 0.03)
#              precision    recall  f1-score   support
#
#         neg       0.82      0.36      0.50       405
#         pos       0.75      0.96      0.84       795
#
# avg / total       0.77      0.76      0.73      1200
#
# [ 0.84297521  0.7107438   0.76859504  0.76033058  0.76033058  0.79831933
#   0.76470588  0.75630252  0.83193277  0.75630252]
# Accuracy of SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=5, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=None, shuffle=True,
#        verbose=0, warm_start=False): 0.78 (+/- 0.07)
#              precision    recall  f1-score   support
#
#         neg       0.68      0.60      0.64       405
#         pos       0.81      0.86      0.83       795
#
# avg / total       0.77      0.77      0.77      1200
#
# [ 0.66115702  0.66115702  0.66115702  0.66115702  0.66115702  0.66386555
#   0.66386555  0.66386555  0.66386555  0.66386555]
# Accuracy of SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False): 0.66 (+/- 0.00)
#              precision    recall  f1-score   support
#
#         neg       0.00      0.00      0.00       405
#         pos       0.66      1.00      0.80       795
#
# avg / total       0.44      0.66      0.53      1200
# /Users/alihamdi/anaconda/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [ 0.83471074  0.70247934  0.7768595   0.78512397  0.78512397  0.76470588
#   0.80672269  0.73109244  0.8487395   0.77310924]
# Accuracy of LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0): 0.78 (+/- 0.08)
#              precision    recall  f1-score   support
#
#         neg       0.71      0.59      0.65       405
#         pos       0.81      0.88      0.84       795
#
# avg / total       0.78      0.78      0.78      1200
#
# [ 0.81818182  0.74380165  0.80165289  0.79338843  0.78512397  0.78991597
#   0.82352941  0.7394958   0.83193277  0.76470588]
# Accuracy of NuSVC(cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#    max_iter=-1, nu=0.5, probability=False, random_state=None,
#    shrinking=True, tol=0.001, verbose=False): 0.79 (+/- 0.06)
#              precision    recall  f1-score   support
#
#         neg       0.71      0.63      0.67       405
#         pos       0.82      0.87      0.85       795
#
# avg / total       0.78      0.79      0.79      1200
